# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Threats (1).csv')

# %%
data.head()
# Out:
#    Unnamed: 0     id       dur proto service state  spkts  dpkts  sbytes  \
# 0       40000  40001  0.012996   tcp       -   FIN     16     18    1540
# 1       40001  40002  0.004119   tcp       -   FIN     12     12    1064
# 2       40002  40003  0.000988   udp     dns   CON      2      2     146
# 3       40003  40004  3.415787   tcp     ssh   FIN    230    238   24344
# 4       40004  40005  0.193943   tcp       -   FIN     72     74    4238
#
#    dbytes  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0    1644  ...                 1               6             0           0
# 1    2260  ...                 1               1             0           0
# 2     178  ...                 1               2             0           0
# 3   29556  ...                 1               1             0           0
# 4   63618  ...                 1               5             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  attack_cat  \
# ...

# %%
data=data.drop(['Unnamed: 0'],axis=1)

# %%
titles = list(data)[1:-1]

# %%
data['service'] = data['service'].replace('-', 'dns')

# %%
from sklearn.preprocessing import LabelEncoder
le_proto = LabelEncoder()
le_service = LabelEncoder()
le_state = LabelEncoder()
le_attack_cat = LabelEncoder()

# %%
data['proto'] = le_proto.fit_transform(data['proto'])
data['service'] = le_proto.fit_transform(data['service'])
data['state'] = le_proto.fit_transform(data['state'])
data['attack_cat'] = le_proto.fit_transform(data['attack_cat'])
data.head()
# Out:
#       id       dur  proto  service  state  spkts  dpkts  sbytes  dbytes  \
# 0  40001  0.012996    111        1      1     16     18    1540    1644
# 1  40002  0.004119    111        1      1     12     12    1064    2260
# 2  40003  0.000988    117        1      0      2      2     146     178
# 3  40004  3.415787    111       10      1    230    238   24344   29556
# 4  40005  0.193943    111        1      1     72     74    4238   63618
#
#           rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0  2539.242797  ...                 1               6             0
# 1  5583.879675  ...                 1               1             0
# 2  3036.437382  ...                 1               2             0
# 3   136.718127  ...                 1               1             0
# 4   747.642372  ...                 1               5             0
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# ...

# %%
X= data.drop(['attack_cat'],axis=1)
y= data['attack_cat']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=40)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators =500, random_state = 42,max_depth=12,min_samples_split=5,max_features='log2')
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=12, max_features='log2', min_samples_split=5,
#                        n_estimators=500, random_state=42)

# %%
from sklearn.metrics import accuracy_score
y_pred = rf_model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8343861982341424

# %%
from sklearn.metrics import f1_score
f1_score(y_test, y_pred, average='weighted')
# Out:
# 0.8132211410147249

# %%
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# 0.8081250189194372

# %%
from sklearn.metrics import precision_score
precision_score(y_test, y_pred, average='weighted')
# Out:
# 0.8414971500493933
