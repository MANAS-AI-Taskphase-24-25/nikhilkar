# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Threats (1).csv')

# %%
data.head()
# Out:
#    Unnamed: 0     id       dur proto service state  spkts  dpkts  sbytes  \
# 0       40000  40001  0.012996   tcp       -   FIN     16     18    1540
# 1       40001  40002  0.004119   tcp       -   FIN     12     12    1064
# 2       40002  40003  0.000988   udp     dns   CON      2      2     146
# 3       40003  40004  3.415787   tcp     ssh   FIN    230    238   24344
# 4       40004  40005  0.193943   tcp       -   FIN     72     74    4238
#
#    dbytes  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0    1644  ...                 1               6             0           0
# 1    2260  ...                 1               1             0           0
# 2     178  ...                 1               2             0           0
# 3   29556  ...                 1               1             0           0
# 4   63618  ...                 1               5             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  attack_cat  \
# ...

# %%
data['service'] = data['service'].replace('-', 'dns')   #Frequency encoding the missing service rows

# %%
from sklearn.preprocessing import LabelEncoder
le_proto = LabelEncoder()
le_service = LabelEncoder()
le_state = LabelEncoder()
le_attack_cat = LabelEncoder()

# %%
data['proto'] = le_proto.fit_transform(data['proto'])
data['service'] = le_service.fit_transform(data['service'])
data['state'] = le_state.fit_transform(data['state'])
data['attack_cat'] = le_attack_cat.fit_transform(data['attack_cat'])
data.head()
# Out:
#    Unnamed: 0     id       dur  proto  service  state  spkts  dpkts  sbytes  \
# 0       40000  40001  0.012996    111        1      1     16     18    1540
# 1       40001  40002  0.004119    111        1      1     12     12    1064
# 2       40002  40003  0.000988    117        1      0      2      2     146
# 3       40003  40004  3.415787    111       10      1    230    238   24344
# 4       40004  40005  0.193943    111        1      1     72     74    4238
#
#    dbytes  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0    1644  ...                 1               6             0           0
# 1    2260  ...                 1               1             0           0
# 2     178  ...                 1               2             0           0
# 3   29556  ...                 1               1             0           0
# 4   63618  ...                 1               5             0           0
#
# ...

# %%
X= data.drop(['attack_cat'],axis=1)    # Separating output label from feature dataset
y= data['attack_cat']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=44,stratify=y)

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier(max_depth= None,max_features=None,min_samples_leaf=2,min_impurity_decrease=0.000001,ccp_alpha=0.0001,random_state=44,splitter='best')

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0001, min_impurity_decrease=1e-06,
#                        min_samples_leaf=2, random_state=44)

# %%
model.score(X_test, y_test)
# Out:
# 0.8358003103218974

# %%
 # Probability of each class
pp=model.predict_proba(X_test)
print(pp)
# Out:
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [5.29997310e-02 5.13855260e-02 3.40328222e-01 ... 5.13855260e-02
#   2.42130751e-03 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 1.37184116e-01 ... 3.61010830e-03
#   6.60649819e-01 0.00000000e+00]
#  [0.00000000e+00 9.11577028e-04 3.19051960e-03 ... 0.00000000e+00
#   5.01367366e-03 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 3.49267948e-02 ... 1.76397954e-04
#   0.00000000e+00 0.00000000e+00]]

# %%
predictions=model.predict(X_test)
print(predictions)
# Out:
# [6 6 3 ... 8 4 3]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, predictions)
# Out:
# 0.8358003103218974

# %%
from sklearn.metrics import precision_score
precision_score(y_test, predictions,average='weighted')
# Out:
# 0.8400240530489297

# %%
from sklearn.metrics import f1_score
f1_score(y_test, predictions,average='weighted')
# Out:
# 0.8284185550157472

# %%
from sklearn.metrics import recall_score
recall_score(y_test, predictions,average='weighted')
# Out:
# 0.8358003103218974

# %%
data.head()
# Out:
#    Unnamed: 0     id       dur  proto  service  state  spkts  dpkts  sbytes  \
# 0       40000  40001  0.012996    111        1      1     16     18    1540
# 1       40001  40002  0.004119    111        1      1     12     12    1064
# 2       40002  40003  0.000988    117        1      0      2      2     146
# 3       40003  40004  3.415787    111       10      1    230    238   24344
# 4       40004  40005  0.193943    111        1      1     72     74    4238
#
#    dbytes  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0    1644  ...                 1               6             0           0
# 1    2260  ...                 1               1             0           0
# 2     178  ...                 1               2             0           0
# 3   29556  ...                 1               1             0           0
# 4   63618  ...                 1               5             0           0
#
# ...

# %%
plt.figure(figsize=(100, 100))
class_names = le_attack_cat.classes_
# Plot the decision tree with the actual feature names
tree.plot_tree(model,
               filled=True,
               fontsize=8,
               class_names=class_names,
               feature_names=X_train.columns)  # Pass the feature names here

plt.show()

# %% [markdown]
# A decent precision score of 0.84 has been obtained for this dataset
