# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("Train.csv")
test_data = pd.read_csv("Test.csv")

# %%
train_data
# Out:
#       Unnamed: 0                                           Name   Location  \
# 0              0            Tata Tiago 1.2 Revotron XZ WO Alloy  Hyderabad
# 1              1     Mahindra TUV 300 2015-2019 mHAWK100 T8 AMT      Kochi
# 2              2         Skoda Rapid 2013-2016 1.6 MPI Ambition     Mumbai
# 3              3                        Tata Indica V2 DLS BSII     Jaipur
# 4              4           Tata Manza Club Class Quadrajet90 LX     Mumbai
# ...          ...                                            ...        ...
# 3745        3745                                    BMW X5 3.0d    Chennai
# 3746        3746  Mahindra Scorpio 2009-2014 VLX 4WD AT 7S BSIV      Delhi
# 3747        3747                        Maruti Wagon R LXI BSII  Ahmedabad
# 3748        3748                 Renault Duster 85PS Diesel RxL  Hyderabad
# 3749        3749                       Maruti Wagon R VXI BS IV    Kolkata
#
# ...

# %%
test_data
# Out:
#       Unnamed: 0                           Name    Location  Year  \
# 0              0         Maruti Swift Dzire VDI   Hyderabad  2013
# 1              1          Hyundai i10 Sportz AT       Delhi  2012
# 2              2  Hyundai Elite i20 Sportz Plus       Kochi  2017
# 3              3                  Volvo XC60 D5        Pune  2011
# 4              4          Hyundai i10 Magna 1.2       Delhi  2013
# ...          ...                            ...         ...   ...
# 1245        1245     Hyundai Elantra CRDi SX AT       Delhi  2013
# 1246        1246           Hyundai Getz GLS ABS        Pune  2005
# 1247        1247         Volkswagen Polo GT TSI  Coimbatore  2017
# 1248        1248       Hyundai Verna SX CRDi AT        Pune  2012
# 1249        1249        Maruti Baleno Alpha CVT       Kochi  2019
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 84175    Diesel       Manual      First   23.4 kmpl
# ...

# %%
def get(value):
    try:
        return float(value.split()[0])
    except:
        return np.nan

# %%
for i in ['Mileage', 'Engine', 'Power']:
    train_data[i] = train_data[i].apply(get)
    test_data[i] = test_data[i].apply(get)
test_data = test_data.dropna()
train_data = train_data.dropna()

# %%
train_data['Fuel_Type'] = train_data['Fuel_Type'].replace({'Petrol': 1, 'Diesel': 0})
train_data
test_data['Fuel_Type'] = test_data['Fuel_Type'].replace({'Petrol': 1, 'Diesel': 0})
test_data
# Out:
# <ipython-input-154-984839298157>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_data['Fuel_Type'] = train_data['Fuel_Type'].replace({'Petrol': 1, 'Diesel': 0})
# <ipython-input-154-984839298157>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Fuel_Type'] = train_data['Fuel_Type'].replace({'Petrol': 1, 'Diesel': 0})
# ...

# %%
train_data['Transmission'] = train_data['Transmission'].replace({'Manual': 1, 'Automatic': 0})
train_data
test_data['Transmission'] = test_data['Transmission'].replace({'Manual': 1, 'Automatic': 0})
test_data
# Out:
# <ipython-input-155-0d60a3072d34>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_data['Transmission'] = train_data['Transmission'].replace({'Manual': 1, 'Automatic': 0})
# <ipython-input-155-0d60a3072d34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Transmission'] = train_data['Transmission'].replace({'Manual': 1, 'Automatic': 0})
# ...

# %%
train_data[['Owner_Type_Fourth & Above', 'Owner_Type_Second', 'Owner_Type_Third']] = train_data[['Owner_Type_Fourth & Above', 'Owner_Type_Second', 'Owner_Type_Third']].astype(int)
train_data
test_data[['Owner_Type_Fourth & Above', 'Owner_Type_Second', 'Owner_Type_Third']] = test_data[['Owner_Type_Fourth & Above', 'Owner_Type_Second', 'Owner_Type_Third']].astype(int)
test_data
# Out:
#       Unnamed: 0                           Name    Location  Year  \
# 0              0         Maruti Swift Dzire VDI   Hyderabad  2013
# 1              1          Hyundai i10 Sportz AT       Delhi  2012
# 2              2  Hyundai Elite i20 Sportz Plus       Kochi  2017
# 3              3                  Volvo XC60 D5        Pune  2011
# 4              4          Hyundai i10 Magna 1.2       Delhi  2013
# ...          ...                            ...         ...   ...
# 1245        1245     Hyundai Elantra CRDi SX AT       Delhi  2013
# 1246        1246           Hyundai Getz GLS ABS        Pune  2005
# 1247        1247         Volkswagen Polo GT TSI  Coimbatore  2017
# 1248        1248       Hyundai Verna SX CRDi AT        Pune  2012
# 1249        1249        Maruti Baleno Alpha CVT       Kochi  2019
#
#       Kilometers_Driven  Fuel_Type  Transmission  Mileage  Engine   Power  \
# 0                 84175          0             1    23.40  1248.0   74.00
# ...

# %%
xf = ['Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power', 'Seats', 'Fuel_Type', 'Transmission', 'Owner_Type_Fourth & Above', 'Owner_Type_Second', 'Owner_Type_Third']
X_train = train_data[xf].values
y_train = train_data['Price'].values
X_test = test_data[xf].values
y_test = test_data['Price'].values

# %%
X_train_min = X_train.min(axis=0)
X_train_max = X_train.max(axis=0)
X_train = (X_train - X_train_min) / (X_train_max - X_train_min)
X_test = (X_test - X_train_min) / (X_train_max - X_train_min)

# %%
np.random.seed(0)
w = np.random.rand(X_train.shape[1])
bias = 0.0
rate = 0.001
iterations = 10000
m = len(y_train)

# %%
loss_history = []

for i in range(iterations):
    y_pred = np.dot(X_train, w) + bias
    error = y_pred - y_train
    mse_loss = np.mean(error ** 2)
    loss_history.append(mse_loss)

    weights_gradient = (2/m) * np.dot(X_train.T, error)
    bias_gradient = (2/m) * np.sum(error)

    w -= rate * weights_gradient
    bias -= rate * bias_gradient

y_test_pred = np.dot(X_test, w) + bias

# %%
if np.isnan(y_test).any() or np.isnan(y_test_pred).any():
    y_train = np.nan_to_num(y_train, nan=np.nanmean(y_train))
    y_test_pred = np.nan_to_num(y_test_pred, nan=np.nanmean(y_test_pred))
y_mean = np.mean(y_test)
total = np.sum((y_test - y_mean) ** 2)
residual = np.sum((y_test - y_test_pred) ** 2)
r2 = 1-(residual / total)
print("R^2:", r2)
# Out:
# R^2: 0.5640420345256856

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(iterations), loss_history, color="r", label="Loss")
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.title("Loss vs. Iterations")
plt.legend()
plt.grid(True)
plt.show()
plt.figure(figsize=(10, 6))

# Scatter plot of the actual price vs the pedicted price
plt.scatter(y_train, y_pred, color = 'r')

# Line plot of the best-fit line (model predictions)
plt.plot([min(y_test), max(y_pred)], [min(y_test), max(y_pred)], 'k:')

# Add labels and title
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted prices')
plt.show()
